# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
model = Sequential()
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='rmsprop',loss='mse')

# %%
df = pd.read_csv("/home/hu3b1188/programs/polynote-0.4.1/examples/Udemy-TF-Keras/DATA/fake_reg.csv")

# %%
X = df[['feature1','feature2']].values
y = df['price'].values
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model.fit(X_train,y_train,epochs=250)
# Out:
# Train on 700 samples
# Epoch 1/250
# 700/700 [==============================] - 1s 799us/sample - loss: 256818.4128
# Epoch 2/250
# 700/700 [==============================] - 0s 44us/sample - loss: 256715.7860
# Epoch 3/250
# 700/700 [==============================] - 0s 80us/sample - loss: 256670.1054
# Epoch 4/250
# 700/700 [==============================] - 0s 91us/sample - loss: 256628.3178
# Epoch 5/250
# 700/700 [==============================] - 0s 46us/sample - loss: 256534.4284
# Epoch 6/250
# 700/700 [==============================] - 0s 96us/sample - loss: 256444.5998
# Epoch 7/250
# 700/700 [==============================] - 0s 46us/sample - loss: 256354.9837
# Epoch 8/250
# 700/700 [==============================] - 0s 96us/sample - loss: 256261.5188
# Epoch 9/250
# 700/700 [==============================] - 0s 86us/sample - loss: 256163.5755
# Epoch 10/250
# 700/700 [==============================] - 0s 64us/sample - loss: 256058.9926
# Epoch 11/250
# 700/700 [==============================] - 0s 55us/sample - loss: 255946.8654
# Epoch 12/250
# 700/700 [==============================] - 0s 66us/sample - loss: 255825.2345
# Epoch 13/250
# 700/700 [==============================] - 0s 94us/sample - loss: 255693.2882
# Epoch 14/250
# 700/700 [==============================] - 0s 63us/sample - loss: 255549.2263
# Epoch 15/250
# 700/700 [==============================] - 0s 63us/sample - loss: 255391.7402
# Epoch 16/250
# 700/700 [==============================] - 0s 62us/sample - loss: 255219.7660
# Epoch 17/250
# 700/700 [==============================] - 0s 64us/sample - loss: 255031.7743
# Epoch 18/250
# 700/700 [==============================] - 0s 95us/sample - loss: 254825.7497
# Epoch 19/250
# 700/700 [==============================] - 0s 79us/sample - loss: 254603.1980
# Epoch 20/250
# 700/700 [==============================] - 0s 58us/sample - loss: 254360.6313
# Epoch 21/250
# 700/700 [==============================] - 0s 86us/sample - loss: 254098.5267
# Epoch 22/250
# 700/700 [==============================] - 0s 86us/sample - loss: 253815.7939
# Epoch 23/250
# 700/700 [==============================] - 0s 88us/sample - loss: 253509.1565
# Epoch 24/250
# 700/700 [==============================] - 0s 69us/sample - loss: 253178.9741
# Epoch 25/250
# 700/700 [==============================] - 0s 75us/sample - loss: 252824.0656
# Epoch 26/250
# 700/700 [==============================] - 0s 63us/sample - loss: 252442.1463
# Epoch 27/250
# 700/700 [==============================] - 0s 95us/sample - loss: 252030.8787
# Epoch 28/250
# 700/700 [==============================] - 0s 60us/sample - loss: 251591.8598
# Epoch 29/250
# 700/700 [==============================] - 0s 59us/sample - loss: 251122.2454
# Epoch 30/250
# 700/700 [==============================] - 0s 65us/sample - loss: 250620.3223
# Epoch 31/250
# 700/700 [==============================] - 0s 65us/sample - loss: 250085.3702
# Epoch 32/250
# Epoch 250/250
# 700/700 [==============================] - 0s 127us/sample - loss: 41.0703

# %%
loss = model.history.history['loss']

# %%
sns.lineplot(x=range(len(loss)),y=loss)
plt.title("Training Loss per Epoch")
# Out:
# Text(0.5, 1.0, 'Training Loss per Epoch')

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /home/hu3b1188/programs/anaconda3/envs/gman/lib/python3.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# /home/hu3b1188/programs/anaconda3/envs/gman/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# IPython             asyncio             jedi                resource
# PIL                 asyncore            jinja2              rlcompleter
# __future__          atexit              joblib              rmagic
# _abc                attr                json                rsa
# _argon2_cffi_bindings attrs               jsonschema          runpy
# _ast                audioop             jupyter             sched
# _asyncio            autoreload          jupyter_client      scipy
# _bisect             backcall            jupyter_console     seaborn
# _blake2             base64              jupyter_core        secrets
# _bootlocale         bdb                 jupyterlab_pygments select
# _bz2                binascii            jupyterlab_widgets  selectors
# _cffi_backend       binhex              keras_applications  send2trash
# _codecs             bisect              keras_preprocessing setuptools
# _codecs_cn          bleach              keyword             shelve
# _codecs_hk          builtins            kiwisolver          shlex
# _codecs_iso2022     bz2                 lib2to3             shutil
# _codecs_jp          cProfile            linecache           signal
# _codecs_kr          cached_property     locale              site
# _codecs_tw          cachetools          logging             six
# _collections        calendar            lxml                sklearn
# _collections_abc    certifi             lzma                smtpd
# _compat_pickle      cffi                macpath             smtplib
# _compression        cgi                 mailbox             sndhdr
# _contextvars        cgitb               mailcap             socket
# _crypt              charset_normalizer  markdown            socketserver
# _csv                chunk               markupsafe          spwd
# _ctypes             cmath               marshal             sqlite3
# _ctypes_test        cmd                 math                sre_compile
# _curses             code                matplotlib          sre_constants
# _curses_panel       codecs              matplotlib_inline   sre_parse
# _datetime           codeop              mimetypes           ssl
# _decimal            collections         mistune             stat
# _distutils_hack     colorsys            mmap                statistics
# _dummy_thread       compileall          modulefinder        storemagic
# _elementtree        concurrent          multiprocessing     string
# _functools          configparser        nbclient            stringprep
# _hashlib            contextlib          nbconvert           struct
# _heapq              contextvars         nbformat            subprocess
# _imp                copy                nest_asyncio        sunau
# _io                 copyreg             netrc               symbol
# _json               crypt               nis                 sympyprinting
# _locale             csv                 nntplib             symtable
# _lsprof             ctypes              notebook            sys
# _lzma               curses              ntpath              sysconfig
# _markupbase         cycler              nturl2path          syslog
# _md5                cythonmagic         numbers             tabnanny
# _multibytecodec     dataclasses         numpy               tarfile
# _multiprocessing    datetime            oauthlib            telnetlib
# _opcode             dateutil            opcode              tempfile
# _operator           dbm                 operator            tensorboard
# _osx_support        debugpy             opt_einsum          tensorflow
# _pickle             decimal             optparse            tensorflow_core
# _posixsubprocess    decorator           os                  tensorflow_estimator
# _py_abc             defusedxml          ossaudiodev         termcolor
# _pydecimal          difflib             packaging           terminado
# _pyio               dis                 pandas              termios
# _pyrsistent_version distutils           pandocfilters       test
# _queue              doctest             parser              testpath
# _random             dummy_threading     parso               tests
# _sha1               email               pasta               textwrap
# _sha256             encodings           pathlib             this
# _sha3               ensurepip           pdb                 threading
# _sha512             entrypoints         pexpect             time
# _signal             enum                pickle              timeit
# _sitebuiltins       errno               pickleshare         tkinter
# _socket             faulthandler        pickletools         token
# _sqlite3            fcntl               pip                 tokenize
# _sre                filecmp             pipes               tornado
# _ssl                fileinput           pkg_resources       trace
# _stat               fnmatch             pkgutil             traceback
# _string             formatter           platform            tracemalloc
# _strptime           fractions           plistlib            traitlets
# _struct             ftplib              poplib              tty
# _symtable           functools           posix               turtle
# _sysconfigdata_aarch64_conda_cos7_linux_gnu gast                posixpath           turtledemo
# _sysconfigdata_aarch64_conda_linux_gnu gc                  pprint              types
# _sysconfigdata_i686_conda_cos6_linux_gnu genericpath         profile             typing
# _sysconfigdata_m_linux_x86_64-linux-gnu getopt              prometheus_client   typing_extensions
# _sysconfigdata_powerpc64le_conda_cos7_linux_gnu getpass             prompt_toolkit      unicodedata
# _sysconfigdata_s390x_conda_cos7_linux_gnu gettext             pstats              unittest
# _sysconfigdata_s390x_conda_linux_gnu glob                pty                 urllib
# _sysconfigdata_x86_64_apple_darwin13_4_0 google_auth_oauthlib ptyprocess          urllib3
# _sysconfigdata_x86_64_conda_cos6_linux_gnu grp                 pvectorc            uu
# _sysconfigdata_x86_64_conda_cos7_linux_gnu grpc                pwd                 uuid
# _sysconfigdata_x86_64_conda_linux_gnu gzip                py_compile          venv
# _testbuffer         h5py                pyasn1              warnings
# _testcapi           hashlib             pyasn1_modules      wave
# _testimportmultiple heapq               pyclbr              wcwidth
# _testmultiphase     hmac                pycparser           weakref
# _thread             html                pydoc               webbrowser
# _threading_local    http                pydoc_data          webencodings
# _tkinter            idlelib             pyexpat             werkzeug
# _tracemalloc        idna                pygments            wheel
# _warnings           imaplib             pylab               widgetsnbextension
# _weakref            imghdr              pyparsing           wrapt
# _weakrefset         imp                 pyrsistent          wsgiref
# _xxtestfuzz         importlib           pytz                xdrlib
# abc                 importlib_metadata  qtconsole           xml
# absl                importlib_resources qtpy                xmlrpc
# aifc                inspect             queue               xxlimited
# antigravity         io                  quopri              xxsubtype
# argon2              ipaddress           random              zipapp
# argparse            ipykernel           re                  zipfile
# array               ipykernel_launcher  readline            zipimport
# ast                 ipython_genutils    reprlib             zipp
# astor               ipywidgets          requests            zlib
# asynchat            itertools           requests_oauthlib   zmq
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
# /home/hu3b1188/programs/anaconda3/envs/gman/lib/python3.7/pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
